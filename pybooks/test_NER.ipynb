# %%
import pickle

import pandas as pd

df = pd.read_csv('../data/data.csv').rename(columns={'label': 'labels'})

# %%
df
# Out:
#                                                  message labels
# 0      ! У Михаила Гуцериева все-таки появились бабло...    149
# 1      !? Еще пять компаний группы «Россети» меняют ю...    141
# 2      !?В правительстве утвердили размещение голосую...    103
# 3      !?Ожидаем шапито на неделе в нашем цирке народ...    157
# 4      !?Системно значимых банков всё ещё 11. Изменен...   2;48
# ...                                                  ...    ...
# 16604  🪨 Взгляд на компанию: «Мечел» — эффект от отме...     99
# 16605  🪨 Взгляд на компанию: «Мечел»: 3-й кв. 2023 г....     99
# 16606  🪨 Мечел: акции с потенциалом роста свыше 90% д...     99
# 16607  🪨 Мечел: анализ ключевых тем. Взгляд БКС  Мы п...     99
# 16608  🫶 АФК Система обещает дивы. Верим?  Основатель...     26
#
# [16609 rows x 2 columns]

# %%
import json
import re
import numpy as np
from abc import abstractmethod


class BaseNERTester:

    @abstractmethod
    def infer_batch(self, input_texts: list[str]) -> list[set[int]]:
        """
        Method to run NER inference

        args:
        - input_texts: list[str] - list of input texts

        returns:
        list[set[int]] - list of sets of recognized entities
        """
        pass


class RegexNERTester(BaseNERTester):

    def __init__(self, path_to_issuers_json: str):
        self.path_to_issuers_json = path_to_issuers_json
        #
        with open(self.path_to_issuers_json, 'rt', encoding='utf-8') as f:
            data = json.loads(f.read())
        for d in data:
            temp_tickers = [i.strip().lower() for i in d['BGTickers']]
            for i in range(len(d['BGTickers'])):
                d['BGTickers'][i] = d['BGTickers'][i].strip().lower()
                if d['BGTickers'][i].endswith(' rx'):
                    d['BGTickers'][i] = d['BGTickers'][i][:-3].strip()
            d['synonims'] = [i.strip().lower() for i in d['synonims']]
        self.issuerid2keys = {
            d['issuerid']: set(d['BGTickers']+d['synonims']+[d['company_name_lower'].strip().lower()])
            for d in data
        }
    
    def infer_batch(self, input_texts: list[str]) -> list[set[int]]:
        res = []
        for text in input_texts:
            text_lower = text.lower()
            res_text = set()
            for issuer_id, keys in self.issuerid2keys.items():
                for key in keys:
                    if key in text_lower:
                        res_text.add(issuer_id)
                        break
            res.append(res_text)
        return res


def run_test(tester: BaseNERTester, df: pd.DataFrame, batch_size: int) -> dict[str, float]:
    texts = df['message']
    results = []
    for batch in np.array_split(texts, batch_size):
        results_batch = tester.infer_batch(texts)
        results.extend(results_batch)
    df['predicted'] = results
    return df

# %%
# %%time

tester = RegexNERTester('../data/issuers_filtered.json')
predicted_df = run_test(tester, df, 1)
# Out:
# CPU times: total: 766 ms
# Wall time: 6.67 s

# %%
i = 2
print(predicted_df.iloc[i]['labels'])
print(predicted_df.iloc[i]['predicted'])
print(predicted_df.iloc[i]['message'])
# Out:
# 103
# {142, 7}
# !?В правительстве утвердили размещение голосующих акций «Ростелекома» в рамках допэмиссии по закрытой подписке в пользу ВТБ по цене 93,21 руб. Предполагается, что ВТБ выкупит акции «Ростелекома» на общую сумму 66 млрд руб. - Ъ  Новость вышла через 1 мин после закрытия основной сессии на Московской бирже @finascop

# %%
df
# Out:
#                                                  message labels  \
# 0      ! У Михаила Гуцериева все-таки появились бабло...    149
# 1      !? Еще пять компаний группы «Россети» меняют ю...    141
# 2      !?В правительстве утвердили размещение голосую...    103
# 3      !?Ожидаем шапито на неделе в нашем цирке народ...    157
# 4      !?Системно значимых банков всё ещё 11. Изменен...   2;48
# ...                                                  ...    ...
# 16604  🪨 Взгляд на компанию: «Мечел» — эффект от отме...     99
# 16605  🪨 Взгляд на компанию: «Мечел»: 3-й кв. 2023 г....     99
# 16606  🪨 Мечел: акции с потенциалом роста свыше 90% д...     99
# 16607  🪨 Мечел: анализ ключевых тем. Взгляд БКС  Мы п...     99
# 16608  🫶 АФК Система обещает дивы. Верим?  Основатель...     26
#
#                                                predicted
# 0                                                  {149}
# 1      {134, 135, 136, 137, 138, 139, 140, 83, 123, 223}
# 2                                               {142, 7}
# 3                              {4, 7, 27, 150, 123, 223}
# 4                          {2, 7, 44, 48, 211, 150, 123}
# ...                                                  ...
# 16604                                      {123, 99, 78}
# 16605                                  {123, 65, 99, 78}
# 16606                                 {123, 99, 133, 78}
# 16607                                          {123, 99}
# 16608                                {204, 26, 123, 100}
#
# [16609 rows x 3 columns]

# %%
data_pred = df.to_dict('records')
for row in data_pred:
    true_set = set([int(i) for i in row['labels'].split(';')])
    row['res'] = len(true_set.intersection(row['predicted'])) == len(true_set)
df_res = pd.DataFrame(data_pred)
df_res['res'].sum()/len(df_res)
# Out:
# 0.9348545969052923

# %%
tester.issuerid2keys
# Out:
# {1: {'derz', 'derzhava', 'derzp', 'держава'},
#  2: {'cbom',
#   'credit bank',
#   'credit bank of moscow',
#   'мкб',
#   'московский кредитный банк'},
#  3: {'rdrb',
#   'roads bank',
#   'rosdorbank',
#   'russian public joint-stock commercial roads bank',
#   'дорожный банк',
#   'рдбанк',
#   'росдорбанк',
#   'российский акционерный коммерческий дорожный банк'},
#  4: {'alrosa', 'alrs', 'алроса'},
#  5: {'avan', 'avangard', 'авангард'},
#  6: {'bank "primorye"',
#   'bank primorye',
#   'pjscb "primorye"',
#   'pjscb primorye',
#   'primbank',
#   'prmb',
#   'public joint-stock commercial bank "primorye"',
#   'акб "приморье"',
#   'акб приморье',
#   'банк "приморье"',
#   'банк приморье',
#   'приморье'},
#  7: {'vtb', 'vtbr', 'банк втб', 'втб'},
#  8: {'irgz',
#   'irkutskenergo',
#   'иркутское энергетики и электрификации',
#   'иркутскэнерго',
#   'иркэнерго'},
#  9: {'kazanorgsintez', 'kzos', 'казаньоргсинтез', 'органический синтез'},
#  10: {'lenzoloto', 'lnzl', 'лензолото'},
#  11: {'rual', 'rusal', 'объединённая компания "русал"', 'русал'},
#  12: {'en+ group', 'en+ group plc', 'enpg', 'enpl', 'эн+ груп'},
#  13: {'belon', 'blng', 'белон'},
#  14: {'dzrd', 'дзрд', 'донской завод радиодеталей'},
#  15: {'levenhuk', 'lvhk', 'левенгук'},
#  16: {'lesk',
#   'lpsb',
#   'lpsbg',
#   'липецкая энергосбытовая компания',
#   'липецкая эск',
#   'лэск'},
#  17: {'mrku',
#   'rosseti ural',
#   'межрегиональная распределительная сетевая компания урала',
#   'мрск урала',
#   'россети урал'},
#  18: {'msst', 'multisistema', 'мультисистема'},
#  19: {'npof',
#   'npofizika',
#   'научно-производственное объединение "физика"',
#   'нпо "физика"',
#   'нпо физика',
#   'физика'},
#  20: {'mgnz', 'mgnzg', 'оао "смз"', 'оао смз', 'соликамский магниевый завод'},
#  21: {'aqua',
#   'inarctica',
#   'инаркт1р1',
#   'инарктика',
#   'русская аквакультура',
#   'русское море'},
#  22: {'abraudurso',
#   'abrd',
#   'абрау - дюрсо',
#   'абрау дюрсо',
#   'абрау – дюрсо',
#   'абрау-дюрсо'},
#  23: {'utar', 'ютэйр'},
#  24: {'acron', 'akrn', 'акрон'},
#  25: {'bane', 'башнефть'},
#  26: {'afks', 'афк система', 'система'},
#  27: {'alnu', 'alrosa', 'алроса', 'алроса-нюрба'},
#  28: {'aptk', 'аптечная сеть 36,6'},
#  29: {'acko', 'аско-страхование'},
#  30: {'assb', 'астраханская энергосбытовая компания', 'астраханская эсб'},
#  31: {'amez', 'ашинский металлургический завод'},
#  32: {'aeroflot', 'aflt', 'аэрофлот', 'аэрофлот – российские авиалинии'},
#  33: {'bspb',
#   'банк петербург',
#   'банк санкт-петербург',
#   'бспб',
#   'санкт-петербург',
#   'спб банк'},
#  34: {'usbn', 'банк уралсиб'},
#  35: {'bisv', 'башинформсвязь'},
#  36: {'belu', 'beluga', 'белуга', 'белуга групп'},
#  37: {'albk', 'бест эффортс банк'},
#  38: {'brzl', 'бурятзолото'},
#  39: {'vjgz', 'варьеганнефтегаз'},
#  40: {'vlhz', 'владимирский химический завод'},
#  41: {'vgsb', 'волгоградэнергосбыт'},
#  42: {'ogkb', 'вторая генерирующая компания оптового рынка электроэнергии'},
#  43: {'vsyd', 'выборгский судостроительный завод'},
#  44: {'gaza', 'газ', 'группа "газ"', 'группа газ', 'пао "газ"', 'пао газ'},
#  45: {'gazc', 'газкон', 'газкон-ао'},
#  46: {'rostovoblgaz',
#   'rtgz',
#   'газпром газораспределение ростов-на-дону',
#   'газпром рнд',
#   'пао "газпром газораспределение ростов-на-дону"',
#   'ростовоблгаз'},
#  47: {'gazprom neft', 'sibn', 'газпром нефть', 'пао "газпром нефть"'},
#  48: {'gazp', 'gazprom', 'газпром', 'пао "газпром"'},
#  49: {'gas-service', 'gazs', 'газ-сервис', 'пао "газ-сервис"'},
#  50: {'gaz-tec', 'gazt', 'газ-тек', 'газ-тэк'},
#  51: {'gseis',
#   'gtss',
#   'геотек',
#   'геотек сейсморазведка',
#   'пао «геотек сейсморазведка»'},
#  52: {'globaltruck', 'gtrk', 'глобалтрак', 'глобалтрак менеджмент'},
#  53: {'gmkn',
#   'nornickel',
#   'норильский никель',
#   'норникель',
#   'пао "гмк "норильский никель"',
#   'пао "горно-металлургическая компания "норильский никель"'},
#  54: {'grnt',
#   'гит',
#   'городские инновационные технологии',
#   'пао "гит"',
#   'пао «городские инновационные технологии'},
#  55: {'rlmn', 'rollman', 'роллман'},
#  56: {'samolet', 'smlt', 'группа самолет', 'самолет'},
#  57: {'lsrg', 'группа лср', 'лср'},
#  58: {'cherkizovo', 'gche', 'группа черкизово', 'черкизово'},
#  59: {'dagestanskaya energosbytovaya',
#   'dasb',
#   'дагестанская энергосбытовая компания',
#   'дагестанэнергосбыт',
#   'дагсб'},
#  60: {'dvec', 'дальневосточная энергетическая компания', 'дэк'},
#  61: {'fesco', 'fesh', 'дальневосточное морское пароходство', 'двмп'},
#  62: {'detsky mir', 'dsky', 'детмир', 'детский мир'},
#  63: {'gtl', 'gtlc', 'джитиэл'},
#  64: {'eelt',
#   'yevropyeyskaya elyektrotyekhnika',
#   'европейская электротехника'},
#  65: {'zil',
#   'zill',
#   'завод имени и.а. лихачева',
#   'завод имени лихачёва',
#   'зил'},
#  66: {'zvez', 'zvezda', 'звезда'},
#  67: {'igst', "izhstal'", 'ижевский металлургический завод', 'ижсталь'},
#  68: {'idvp', 'invest-development', 'инвест-девелопмент'},
#  69: {'rusi',
#   'russ-invest',
#   'russinvest',
#   'ик русс-инвест',
#   'инвестиционная компания ик русс-инвест',
#   'русс-инвест',
#   'русс-инвест ик',
#   'руссинвест'},
#  70: {'ingr', 'ingrad', 'opin', 'инград', 'инград (пао)', 'пао инград'},
#  71: {'iskj', 'институт стволовых клеток человека', 'искч'},
#  72: {'inter rao',
#   'irao',
#   'интер рао',
#   'интер рао еэс',
#   'интер рао еэс финанс'},
#  73: {'kalujskaya sbytovaya',
#   'klsb',
#   'калужская сбыткомп',
#   'калужская сбытовая компания',
#   'клсб',
#   'кск'},
#  74: {'kamaz', 'kmaz', 'камаз'},
#  75: {'kunf',
#   'kuzocm',
#   'каменск-уральский завод по обработке цветных металлов',
#   'кузоцм'},
#  76: {'quadra',
#   'tgkd',
#   'ао квадра',
#   'квадра',
#   'квадра - генерирующая компания',
#   'пао квадра'},
#  77: {'kmez',
#   'kvmz',
#   'ковровский механический завод',
#   'ковровский мехзд',
#   'пао кмз'},
#  78: {'koks', 'ksgr', 'кокс', 'пао кокс'},
#  79: {'vsmo',
#   'vsmpo-avisma',
#   'vsmpo-avisma corporation',
#   'всмпо',
#   'всмпо-ависма',
#   'всмпо-авсм',
#   'корпорация всмпо-ависма'},
#  80: {'kogk',
#   'korgok',
#   'korshunov mining plant',
#   'коршуновский гок',
#   'коршуновский горно-обогатительный комбинат'},
#  81: {'kgiw', 'kmtz', 'косогорский металлургический завод', 'пао кмз'},
#  82: {'kostromskaya sbytovaya kompaniya',
#   'ksk',
#   'ktsb',
#   'костромская сбытовая компания',
#   'кск'},
#  83: {'kzms',
#   'rosset',
#   'кзмс',
#   'краснокамский завод металлических сеток',
#   'россет'},
#  84: {'krsb', 'krsk-sbit', 'красноярскэнергосбыт'},
#  85: {'kbtk', 'ktk', 'ктк', 'кузбасская топливная компания', 'пао ктк'},
#  86: {'kazt', 'kuazot', 'куйбазот', 'куйбышевазот'},
#  87: {'kgk',
#   'kgkc',
#   'kurgancskaya generiruyushaya',
#   'кгк',
#   'курганская генерирующая компания',
#   'курганская гк',
#   'пао кгк'},
#  88: {'mvid', 'mvideo', 'м.видео', 'мвидео'},
#  89: {'magnit', 'mgnt', 'магнит', 'магнит пао', 'пао магнит'},
#  90: {'magn',
#   'magnitigorskiy metallurgicheskiy',
#   'магнитка',
#   'магнитогорский металлургический комбинат',
#   'ммк'},
#  91: {'megafon', 'mfon', 'мегафон', 'мегафон пао', 'пао мегафон'},
#  92: {'odva', 'медиахолдинг'},
#  93: {'gema',
#   'международный медицинский центр обработки и криохранения биоматериалов'},
#  94: {'mrkz',
#   'межрегиональная распределительная сетевая компания северо-запада'},
#  95: {'mrkp',
#   'межрегиональная распределительная сетевая компания центра и приволжья'},
#  96: {'mrkc', 'межрегиональная распределительная сетевая компания центра'},
#  97: {'merf', 'меридиан'},
#  98: {'mtkb', 'меткомбанк'},
#  99: {'mechel', 'mtlr', 'mtlrp', 'мечел'},
#  100: {'mtc', 'mtss', 'мобильные телесистемы', 'мтс'},
#  101: {'mrsb', 'мордовская энергосбытовая компания'},
#  102: {'mori', 'морион'},
#  103: {'moex', 'мосбиржа', 'московская биржа', 'московская биржа ммвб-ртс'},
#  104: {'mgts', 'московская городская телефонная сеть'},
#  105: {'krot', 'krotp', 'красный октябрь'},
#  106: {'mstt', 'мостотрест'},
#  107: {'nsvz', 'наука-связь'},
#  108: {'irkt', 'иркут'},
#  109: {'uwgn', 'объединенная вагонная компания'},
#  110: {'nfaz', 'нефаз', 'нефтекамский автозавод'},
#  111: {'lkoh', 'лукойл'},
#  112: {'rosn', 'rosneft', 'роснефть'},
#  113: {'nknc', 'nkncp', 'нижнекамскнефтехим'},
#  114: {'nksh', 'nkshp', 'нижнекамскшина'},
#  115: {'novatek', 'nvtk', 'новатэк'},
#  116: {'nlmk', 'нлмк', 'новолипецкий металлургический комбинат'},
#  117: {'nkhp', 'нкхп', 'новороссийский комбинат хлебопродуктов'},
#  118: {'nmtp',
#   'нмтп',
#   'новороссийский морской порт',
#   'новороссийский морской торговый порт'},
#  119: {'nompp', 'новороссийское морское пароходство', 'новошип'},
#  120: {'unac',
#   'объединенная авиастроительная корпорация',
#   'пао "оак"',
#   'пао оак'},
#  121: {'ucss', 'кредитные системы', 'объединенные кредитные системы'},
#  122: {'satr', 'одк сатурн', 'одк-сатурн', 'одк_сатурн', 'сатурн'},
#  123: {'orup', 'ор', 'ор групп', 'пао ор'},
#  124: {'paza', 'павл автобус', 'павлбус', 'павловский автобус'},
#  125: {'pmsb', 'pmsbp', 'пермская энергосбытовая компания', 'пермэнергосбыт'},
#  126: {'pikk', 'пик сз', 'пик-специализированный застройщик'},
#  127: {'plzl', 'полюс'},
#  128: {'rkke', 'ркк «энергия»', 'ркк энергия', 'энергия'},
#  129: {'rasp', 'пао «распадская»', 'распадская'},
#  130: {'rbcm',
#   'гк «росбизнесконсалтинг»',
#   'рбк',
#   'рос бизнес консалтинг',
#   'росбизнесконсалтинг'},
#  131: {'chgz', 'рн-западная сибирь'},
#  132: {'rgsc',
#   'банк росгосстрах',
#   'ргс банк',
#   'росгосстрах',
#   'росгосстрах банк'},
#  133: {'rosinter', 'rost', 'росинтер', 'росинтер ресторантс холдинг'},
#  134: {'mrkv', 'россети волга'},
#  135: {'kube', 'россети кубань'},
#  136: {'lsng', 'россети ленэнерго'},
#  137: {'msrs', 'россети московский регион'},
#  138: {'mrkk', 'россети северный кавказ'},
#  139: {'mrks', 'россети сибирь'},
#  140: {'mrky', 'россети юг'},
#  141: {'rsti', 'российские сети'},
#  142: {'rtkm', 'ростелеком'},
#  143: {'rugr', 'русгрэйн холдинг'},
#  144: {'rolo', 'русолово'},
#  145: {'rusp', 'русполимет'},
#  146: {'rzsb', 'рязанская энергетическая сбытовая компания'},
#  147: {'krkn', 'krknp', 'саратовский нефтеперерабатывающий завод'},
#  148: {'sare', 'sarep', 'саратовэнерго'},
#  149: {'sfin', 'сафмар', 'сафмар финансовые инвестиции'},
#  150: {'sber', 'sberbank', 'сбер', 'сбербанк', 'сбербанк россии'},
#  151: {'svet', 'группа светофор', 'светофор групп'},
#  152: {'chmf', 'северсталь'},
#  153: {'selg', 'селигдар'},
#  154: {'sibg', 'сибирский гостинец'},
#  155: {'mfgs', 'славнефть - мегионнефтегаз'},
#  156: {'jnos', 'jnosp', 'славнефть-ярославнефтеоргсинтез'},
#  157: {'flot', 'совкомфлот', 'современный коммерческий флот'},
#  158: {'sollers', 'svav', 'северсталь-авто', 'соллерс'},
#  159: {'stsb', 'ставропольэнергосбыт'},
#  160: {'sngs', 'сургутнефтегаз'},
#  161: {'krasny kotelshchik',
#   'krkop',
#   'pjsc krasny kotelshchik',
#   'красный котельщик',
#   'ткз "красный котельщик"',
#   'ткз красный котельщик'},
#  162: {'tasb',
#   'tasbp',
#   'тамбовская энергосбытовая компания',
#   'тамбовэнергосбыт'},
#  163: {'tatn', 'tatneft', 'татнефть'},
#  164: {'tattelecom', 'ttlk', 'таттелеком'},
#  165: {'tgc-14',
#   'tgk-14',
#   'tgkn',
#   'тгк-14',
#   'территориальная генерирующая компания № 14'},
#  166: {'tgc-1',
#   'tgk-1',
#   'tgka',
#   'тгк-1',
#   'территориальная генерирующая компания №1'},
#  167: {'tgc-2',
#   'tgk-2',
#   'tgkb',
#   'тгк-2',
#   'территориальная генерирующая компания №2'},
#  168: {'vrsb', 'vrsbp', 'тнс энерго воронеж'},
#  169: {'kbsb', 'kbsbp', 'тнс энерго кубань'},
#  170: {'misb', 'misbp', 'тнс энерго марий эл'},
#  171: {'nnsb',
#   'nnsbp',
#   'тнс энерго нижний новг',
#   'тнс энерго нижний новгород'},
#  172: {'rtsb', 'rtsbp', 'тнс энерго ростов', 'тнс энерго ростов-на-дону'},
#  173: {'yrsb', 'yrsbp', 'тнс энерго ярославль'},
#  174: {'tors', 'россети томск', 'томская распределительная компания', 'трк'},
#  175: {'transneft', 'trnfp', 'транснефть'},
#  176: {'transfin', 'trfm', 'трансфин', 'трансфин-м'},
#  177: {'oao tmk', 'tmk', 'trmk', 'тмк', 'трубная металлургическая компания'},
#  178: {'tuza',
#   'не tza -- есть американский тикер',
#   'пао «тза»',
#   'пао тза',
#   'тза',
#   'туймазинский завод автобетоновозов'},
#  179: {'tuch',
#   'тксм',
#   'тучковский комбинат строительных материалов',
#   'тучковский ксм'},
#  180: {'southern kuzbass coal company',
#   'ukuz',
#   'пао «южный кузбасс»',
#   'пао южный кузбасс',
#   'южный кузбасс'},
#  181: {'arsa', 'arsagera(не встречал упоминаний)', 'арсагера'},
#  182: {'uralkali', 'urka', 'уралкалий'},
#  183: {'urals stampings plant', 'urkz', 'уральская кузница'},
#  184: {'life', 'pharmsynthez', 'пао фармсинтез', 'фарм-синтез', 'фармсинтез'},
#  185: {'hydr',
#   'rushydro',
#   'пао русгидро',
#   'русгидро',
#   'федеральная гидрогенерирующая компания - русгидро'},
#  186: {'ao fgc ues',
#   'fees',
#   'пао россети',
#   'пао фск еэс',
#   'россети фск еэс',
#   'федеральная сетевая компания единой энергетической системы',
#   'фск еэс'},
#  187: {'phor', 'phosagro', 'фосагро'},
#  188: {'himcp', 'himprom', 'пао химпром', 'химпром'},
#  189: {'world trade center',
#   'wtc',
#   'wtcm',
#   'центр международной торговли',
#   'цмт'},
#  190: {'transcontainer', 'trcn', 'пао трансконейнер', 'трансконтейнер'},
#  191: {'central telegraph',
#   'cntl',
#   'пао центральный телеграф',
#   'центральный телеграф'},
#  192: {'prfn',
#   'пао чзпсн-профнастил',
#   'челябинский завод профилированного стального настила',
#   'чзпсн-профнастил'},
#  193: {'ckpz',
#   'oao chelyabinsk forge-and-press plant',
#   'пао челябинский кузнечно-прессовый завод',
#   'челябинский кузнечно-прессовый завод',
#   'чкпз'},
#  194: {'chelyabinsk metallurgical plant',
#   'chmk',
#   'пао чмк',
#   'челябинский металлургический комбинат',
#   'чмк'},
#  195: {'chelyabinsk pipe rolling plant',
#   'chep',
#   'пао чтпз',
#   'челябинский трубопрокатный завод',
#   'чтпз'},
#  196: {'electrozink', 'eltz', 'пао электроцинк', 'электроцинк'},
#  197: {'elfv', 'enel russia', 'enru', 'пао энел россия', 'энел россия'},
#  198: {'unickel',
#   'unkl',
#   'комбинат южуралникель',
#   'пао комбинат южуралникель',
#   'южно-уральский никелевый комбинат',
#   'южуралникель'},
#  199: {'unipro', 'upro', 'пао юнипро', 'юнипро'},
#  200: {'yakg',
#   'yatec',
#   'пао якутская топливно-энергетическая компания',
#   'якутская топливно-энергетическая компания',
#   'ятэк'},
#  201: {'yakutskenergo', 'yken', 'пао якутскэнерго', 'якутскэнерго'},
#  202: {'vozrozhdenie bank',
#   'vzrz',
#   'банк возрождение',
#   'возрождение',
#   'пао банк возрождение'},
#  203: {'kuzb', 'kuzbank', 'банк кузнецкий', 'кузнецкий', 'пао банк кузнецкий'},
#  204: {'segezha', 'segezha group', 'sgzh', 'сегежа', 'сегежа групп'},
#  205: {'tns energo', 'tnse', 'пао гк тнс энерго', 'тнс энерго'},
#  206: {'diod',
#   'diod plant of ecological technics and ecomeals',
#   'диод',
#   'завод экологической техники и экопитания диод',
#   'пао диод'},
#  207: {'mobb', 'московский областной банк'},
#  208: {'nauk', 'наука'},
#  209: {'rnft', 'русснефть'},
#  210: {'omzz',
#   'omzzp',
#   'объединенные машиностроительные заводы (группа уралмаш-ижора)'},
#  211: {'rosb', 'росбанк'},
#  212: {'rgss', 'росгосстрах'},
#  213: {'kche', 'kchep', 'камчатскэнерго'},
#  214: {'mage', 'magep', 'магаданэнерго'},
#  215: {'msng', 'московская\xa0энергетическая компания', 'мосэнерго'},
#  216: {'sago', 'самараэнерго', 'самарэнерго'},
#  217: {'slen', 'сахалинэнерго'},
#  218: {'etalon group (эталон груп пиэлси)',
#   'etln li',
#   'группа эталон',
#   'эталон груп'},
#  219: {'fix price',
#   'fix price group (фикс прайс груп лтд)',
#   'fixp',
#   'fixprice'},
#  220: {'globaltrans',
#   'globaltrans investment (глобалтранс инвестмент плс)',
#   'gltr li',
#   'глобалтранс'},
#  221: {'headhunter', 'headhunter group (хэдхантер групп пиэлси)', 'hhru'},
#  222: {'hms hydraulic machines & systems group (гмс гидравлик машинс энд системс груп плс)',
#   'hmsg'},
#  223: {'mail li',
#   'mail.ru group limited (мэйл.ру груп лимитед)',
#   'vk group',
#   'vkco',
#   'вк',
#   'вконтакте'},
#  224: {'md medical',
#   'md medical group investments (мд медикал груп инвестментс плс)',
#   'mdmg'},
#  225: {'tcs group',
#   'tcs group holding (тисиэс груп холдинг пиэлси)',
#   'tcs li',
#   'tcsg',
#   'tinkoff',
#   'тинькофф'},
#  226: {'okey', "ао о'кей групп"},
#  227: {'five li',
#   'x5 group',
#   'икс 5 ритейл груп н.в. (x5 retail group n.v.)',
#   'х5 групп'},
#  228: {'qiwi', 'ао киви', 'киви пиэлси (qiwi )'},
#  229: {'lent', 'lnta', 'лента'},
#  230: {'ozon', 'озон холдингс пиэлси'},
#  231: {'agro', 'rusagro', 'рос агро плс (ros agro )', 'русагро'},
#  232: {'nord gold (норд голд плк)', 'rtsd'},
#  233: {'nord',
#   'nordgold',
#   'united medical group cy (юнайтед медикал груп ки пиэлси)'},
#  234: {'"петропавловск"',
#   'petropavl',
#   'petropavlovsk (петропавловск плк)',
#   'pogr'},
#  235: {'poly',
#   'polymetal',
#   'полиметалл',
#   'полиметалл интернэшнл плс (polymetal international )'},
#  236: {'yandex',
#   'yndx',
#   'яндекс',
#   'яндекс н.в. (public limited liability company yandex n.v.)'},
#  237: {'noventiq', 'sftl', 'softline', 'softline holding limited', 'софтлайн'},
#  240: {'veon', 'veon .', 'веон'},
#  241: {'posi',
#   'positive group',
#   'positive tech',
#   'гр. позитив',
#   'группа позитив'},
#  251: {'cian', 'циан'},
#  254: {'whoosh', 'wush', 'вуш', 'вуш холдинг'},
#  255: {'spbe', 'спб биржа'},
#  257: {'global ports', 'globalports', 'glpr', 'глобалпортс'},
#  267: {'reni', 'группа ренессанс страхование', 'ренессанс страхование'},
#  258: {'astr', 'astra', 'astra linux', 'астра', 'гк астра', 'группа астра'},
#  261: {'aqua',
#   'inarctica',
#   'аквакультура',
#   'инарктика',
#   'русская аквакультура',
#   'русское море'},
#  265: {'ugld', 'югк', 'южуралзолото'},
#  266: {'abio', 'artgen biotech', 'iартген', 'артген', 'артген биотех'},
#  268: {'geco', 'genetico', 'iгенетико', 'генетико'},
#  269: {'carm', 'carmoney', 'пао "стг"', 'смарттехгрупп'},
#  270: {'henderson', 'hnfg', 'хендерсон'},
#  271: {'sovcombank', 'svcb', 'совкомбанк'},
#  272: {'eutr', 'азс "трасса"', 'азс «трасса»', 'азс трасса', 'евротранс'},
#  273: {'"каршеринг руссия", пао',
#   'deli',
#   'delimobil',
#   'делимобил',
#   'делимобиль',
#   'каршеринг рус',
#   'пао "каршеринг руссия"'},
#  274: {'dias', 'diasoft', 'диасофт'}}

# %%
mentions = pickle.load(open("../data/mentions texts.pickle", "rb"))
mentions.drop(columns=["messageid"], inplace=True)
mentions.drop(index=mentions[mentions.MessageText.str.len() == 0].index, inplace=True)
mentions.drop(index=mentions[mentions.issuerid < 0].index, inplace=True)

# %%
mentions.iloc[0]
# Out:
# ChannelID                                             1197210433
# issuerid                                                      90
# MessageID                                                   5408
# DateAdded                                    2021-02-06 01:42:42
# DatePosted                                   2020-04-29 07:29:01
# MessageText    ?? Фокус недели #ФН  Сегодня ????? ММК опублик...
# IsForward                                                  False
# Name: 0, dtype: object

# %%
mentions['MessageText'].iloc[0]
# Out:
# '?? Фокус недели #ФН  Сегодня ????? ММК опубликует финансовую отчётность за 1 кв. 2020 #MAGN #Отчетность ?????? Магнит представит операционные результаты за 1 кв. 2020 #MGNT #Результаты ?????? Новатэк опубликует финансовую отчётность за 1 кв. 2020 #NVTK #Отчетность ?????? ФРС США представит решение по процентной ставке #ФРС #Макро ?????? Tesla опубликует финансовую отчётность за 1 кв. 2020 #TSLA #Отчетность  ?????? Microsoft опубликует финансовую отчётность за 1 кв. 2020 #MSFT #Отчетность  ?????? Facebook опубликует финансовую отчётность за 1 кв. 2020 #FB #Отчетность  30 апреля ?????? Детский мир опубликует финансовую отчётность по МСФО за 2019 #DSKY #Отчетность ?????? Энел Россия опубликует финансовую отчётность по РСБУ за 1 кв. #ENRU #Отчетность ????? Evraz представит операционные результаты за 1 кв. 2020 #EVR #Результаты ????? НорНикель опубликует производственные результаты за 1 кв. 2020 #GMKN #Результаты ?????? РусГидро представит финансовую отчётность по РСБУ за 1 кв. 2020 #HYDR #Отчетность ????? СД НЛМК рассмотрит дивиденды за 1 кв. 2020 #NLMK #Дивиденды  ?????? Apple опубликует финансовую отчётность за 1 кв. 2020 #AAPL #Отчетность  ?????? Amazon опубликует финансовую отчётность за 1 кв. 2020 #AMZN #Отчетность  ?????? Gilead опубликует финансовую отчётность за 1 кв. 2020 #GILD #Отчетность  1 мая ?????? Торги на МосБирже не проводятся из-за праздников #MOEX #График ?????? Exxon Mobil опубликует финансовую отчетность за 1 кв. 2020 #XOM #Отчетность  ?????? Chevron публикует финансовую отчетность за 1 кв. 2020 #CVX #Отчетность  4 мая ?????? Акции ЦМТ последний день торгуются с дивидендом 0,56 руб. на акцию #WTCM #Дивиденды'
